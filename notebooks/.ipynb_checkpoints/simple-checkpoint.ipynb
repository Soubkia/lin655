# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import math
from collections import defaultdict, namedtuple
from dataclasses import dataclass, field
from enum import Enum
from operator import itemgetter

import nltk

# %%
def trigrams(text):
    for snt in nltk.tokenize.sent_tokenize(text):
        words = [word.lower() for word in nltk.tokenize.word_tokenize(snt) if word.isalpha()]
        for trigram in nltk.ngrams(words, 3):
            yield trigram

# %%
class Label(Enum):
    ADJ = "ADJ"
    ADV = "ADV"
    NOUN = "NOUN"
    PRO = "PRO"
    DET = "DET"
    CONJ = "CONJ"
    PREP = "PREP"
    VERB = "VERB"
    # VERB_PAST = "VERB_PAST"
    # VERB_PROG = "VERB_PROG"
    # NOUN_PLRL = "NOUN_PLRL"

# %% [markdown]
# > The 28 seed words used for English were the following - pronoun: you, we,
# me; verb: come, play, put; preposition: on, out, in; determiner: this, these; noun: baby, car, train,
# box, house, boy, man, book; adjective: big, silly, green; adverb: well, very, now; conjunction: and,
# or, but.

# %%
SEEDS = [
    ("you", Label.PRO),
    ("we", Label.PRO),
    ("me", Label.PRO),
    ("come", Label.VERB),
    ("play", Label.VERB),
    ("put", Label.VERB),
    ("on", Label.PREP),
    ("out", Label.PREP),
    ("in", Label.PREP),
    ("this", Label.DET),
    ("these", Label.DET),
    ("baby", Label.NOUN),
    ("car", Label.NOUN),
    ("train", Label.NOUN),
    ("box", Label.NOUN),
    ("house", Label.NOUN),
    ("boy", Label.NOUN),
    ("man", Label.NOUN),
    ("book", Label.NOUN),
    ("big", Label.ADJ),
    ("silly", Label.ADJ),
    ("green", Label.ADJ),
    ("well", Label.ADV),
    ("very", Label.ADV),
    ("now", Label.ADV),
    ("and", Label.CONJ),
    ("or", Label.CONJ),
    ("but", Label.CONJ)
]

# %%
Frame = namedtuple("Frame", ["left", "right"])


@dataclass
class Model:
    frames: dict = field(default_factory=lambda: defaultdict(lambda: defaultdict(int)))  # frame -> label -> score
    lexicon: dict = field(default_factory=lambda: defaultdict(lambda: defaultdict(int))) # word  -> label -> score
    fthresh: int = field(default=15)
    wthresh: int = field(default=15)
    lframes: dict = field(default_factory=dict)
    rframes: dict = field(default_factory=dict)
    cframes: dict = field(default_factory=dict)
    
    def __post_init__(self):
        for word, lbl in SEEDS:
            self.lexicon[word][lbl] = math.inf
    
    def train(self, text):
        for left, target, right in trigrams(text):
            frame = Frame(left, right)
            wlabel, flabel = self.wlabel(target), self.flabel(frame)
            # The target word is part of the trusted lexicon.
            if wlabel:
                # Update frame labels.
                self.frames[frame][wlabel] += 1
                for lbl in self.frames[frame]:
                    if lbl != wlabel:
                        self.frames[frame][lbl] -= 1
            # The frame is a trusted context.
            if flabel:
                # Update word labels.
                self.lexicon[target][flabel] += 1
                for lbl in self.lexicon[target]:
                    if lbl != flabel:
                        self.lexicon[target][lbl] -= 0.75
            # Consider generalizing lexical frames.
            # if wlabel:
            #     for lbl in Label:
            #         frms = [frm for frm in self.frames if self.flabel(frm) == lbl]
            #         lfreqs = nltk.FreqDist([(self.wlabel(frm.left), frm.right) for frm in frms])
            #         del lfreqs[None]
            #         rfreqs = nltk.FreqDist([(frm.left, self.wlabel(frm.right)) for frm in frms])
            #         del rfreqs[None]
            #         cfreqs = nltk.FreqDist([(self.wlabel(frm.left), self.wlabel(frm.right)) for frm in frms])
            #         for tup in cfreqs:
            #             if None in tup:
            #                 del cfreqs[tup]
            #         # Run the tolerance principle.
            #         self.lframes = {}
            #         for frm in lfreqs:
            #             n = lfreqs.N()
            #             threshold = n - (n / math.log(n))
            #             if lfreqs[frm] > threshold:
            #                 self.lframes[frm] = lbl 
            #         self.rframes = {}
            #         for frm in rfreqs:
            #             n = rfreqs.N()
            #             threshold = n - (n / math.log(n))
            #             if rfreqs[frm] > threshold:
            #                 self.rframes[frm] = lbl
            #         self.cframes = {}
            #         for frm in cfreqs:
            #             n = cfreqs.N()
            #             threshold = n - (n / math.log(n))
            #             if cfreqs[frm] > threshold:
            #                 self.cframes[frm] = lbl
                
    # TODO: This should not be taking the "max"        
    def wlabel(self, word):
        # Retrieve the highest scoring label for the word.
        if word not in self.lexicon:
            return None
        label, score = max(self.lexicon[word].items(), key=itemgetter(1))
        if score <= self.wthresh:
            return None
        return label
    
    def flabel(self, frame):
        if frame not in self.frames:
            # llbl, rlbl = self.wlabel(frame.left), self.wlabel(frame.right)
            # lfrm, rfrm = Frame(llbl, frame.right), Frame(frame.left, rlbl)
            # cfrm = Frame(llbl, rlbl)
            # if llbl and lfrm in self.lframes:
            #     return self.lframes[lfrm]
            # if rlbl and rfrm in self.rframes:
            #     return self.rframes[rfrm]
            # if llbl and rlbl and cfrm in self.cframes:
            #     return self.cframes[cfrm]
            return None
        label, score = max(self.frames[frame].items(), key=itemgetter(1))
        if score <= self.fthresh:
            return None
        return label
    
    def words(self):
        for word in self.lexicon:
            lbl = self.wlabel(word)
            if lbl:
                yield (word, lbl)
                
    def ctxs(self):
        for frm in self.frames:
            lbl = self.flabel(frm)
            if lbl:
                yield (frm, lbl)

# %%
mdl = Model()
mdl.train(" ".join([" ".join(snt) for snt in nltk.corpus.brown.sents()]))

# %%
set(mdl.words()) - set(SEEDS)
# Out:
# {('a', <Label.DET: 'DET'>),
#  ('about', <Label.PREP: 'PREP'>),
#  ('absence', <Label.NOUN: 'NOUN'>),
#  ('across', <Label.PREP: 'PREP'>),
#  ('after', <Label.PREP: 'PREP'>),
#  ('against', <Label.PREP: 'PREP'>),
#  ('all', <Label.PREP: 'PREP'>),
#  ('also', <Label.PREP: 'PREP'>),
#  ('among', <Label.PREP: 'PREP'>),
#  ('amount', <Label.NOUN: 'NOUN'>),
#  ('any', <Label.DET: 'DET'>),
#  ('are', <Label.PREP: 'PREP'>),
#  ('area', <Label.NOUN: 'NOUN'>),
#  ('around', <Label.PREP: 'PREP'>),
#  ('as', <Label.PREP: 'PREP'>),
#  ('at', <Label.PREP: 'PREP'>),
#  ('basis', <Label.NOUN: 'NOUN'>),
#  ('be', <Label.PREP: 'PREP'>),
#  ('because', <Label.PREP: 'PREP'>),
#  ('before', <Label.PREP: 'PREP'>),
#  ('bottle', <Label.NOUN: 'NOUN'>),
#  ('bottom', <Label.NOUN: 'NOUN'>),
#  ('by', <Label.PREP: 'PREP'>),
#  ('called', <Label.PREP: 'PREP'>),
#  ('can', <Label.PREP: 'PREP'>),
#  ('center', <Label.NOUN: 'NOUN'>),
#  ('corner', <Label.NOUN: 'NOUN'>),
#  ('could', <Label.PREP: 'PREP'>),
#  ('couple', <Label.NOUN: 'NOUN'>),
#  ('day', <Label.NOUN: 'NOUN'>),
#  ('department', <Label.NOUN: 'NOUN'>),
#  ('development', <Label.NOUN: 'NOUN'>),
#  ('did', <Label.PREP: 'PREP'>),
#  ('direction', <Label.NOUN: 'NOUN'>),
#  ('do', <Label.PREP: 'PREP'>),
#  ('does', <Label.PREP: 'PREP'>),
#  ('door', <Label.NOUN: 'NOUN'>),
#  ('down', <Label.PREP: 'PREP'>),
#  ('during', <Label.PREP: 'PREP'>),
#  ('edge', <Label.NOUN: 'NOUN'>),
#  ('effect', <Label.NOUN: 'NOUN'>),
#  ('end', <Label.NOUN: 'NOUN'>),
#  ('even', <Label.PREP: 'PREP'>),
#  ('far', <Label.ADV: 'ADV'>),
#  ('felt', <Label.PREP: 'PREP'>),
#  ('for', <Label.PREP: 'PREP'>),
#  ('form', <Label.NOUN: 'NOUN'>),
#  ('found', <Label.PREP: 'PREP'>),
#  ('from', <Label.PREP: 'PREP'>),
#  ('get', <Label.PREP: 'PREP'>),
#  ('going', <Label.PREP: 'PREP'>),
#  ('got', <Label.PREP: 'PREP'>),
#  ('government', <Label.NOUN: 'NOUN'>),
#  ('group', <Label.NOUN: 'NOUN'>),
#  ('had', <Label.PREP: 'PREP'>),
#  ('has', <Label.PREP: 'PREP'>),
#  ('have', <Label.PREP: 'PREP'>),
#  ('he', <Label.PRO: 'PRO'>),
#  ('i', <Label.PRO: 'PRO'>),
#  ('if', <Label.PREP: 'PREP'>),
#  ('image', <Label.NOUN: 'NOUN'>),
#  ('into', <Label.PREP: 'PREP'>),
#  ('is', <Label.PREP: 'PREP'>),
#  ('just', <Label.PREP: 'PREP'>),
#  ('kind', <Label.NOUN: 'NOUN'>),
#  ('lack', <Label.NOUN: 'NOUN'>),
#  ('level', <Label.NOUN: 'NOUN'>),
#  ('light', <Label.NOUN: 'NOUN'>),
#  ('like', <Label.PREP: 'PREP'>),
#  ('list', <Label.NOUN: 'NOUN'>),
#  ('long', <Label.ADV: 'ADV'>),
#  ('lot', <Label.NOUN: 'NOUN'>),
#  ('made', <Label.PREP: 'PREP'>),
#  ('matter', <Label.NOUN: 'NOUN'>),
#  ('means', <Label.NOUN: 'NOUN'>),
#  ('member', <Label.NOUN: 'NOUN'>),
#  ('much', <Label.ADV: 'ADV'>),
#  ('name', <Label.NOUN: 'NOUN'>),
#  ('nature', <Label.NOUN: 'NOUN'>),
#  ('not', <Label.PREP: 'PREP'>),
#  ('number', <Label.NOUN: 'NOUN'>),
#  ('of', <Label.PREP: 'PREP'>),
#  ('office', <Label.NOUN: 'NOUN'>),
#  ('one', <Label.PREP: 'PREP'>),
#  ('only', <Label.PREP: 'PREP'>),
#  ('order', <Label.NOUN: 'NOUN'>),
#  ('over', <Label.PREP: 'PREP'>),
#  ('pair', <Label.NOUN: 'NOUN'>),
#  ('part', <Label.NOUN: 'NOUN'>),
#  ('period', <Label.NOUN: 'NOUN'>),
#  ('piece', <Label.NOUN: 'NOUN'>),
#  ('plane', <Label.NOUN: 'NOUN'>),
#  ('point', <Label.NOUN: 'NOUN'>),
#  ('presence', <Label.NOUN: 'NOUN'>),
#  ('problem', <Label.NOUN: 'NOUN'>),
#  ('process', <Label.NOUN: 'NOUN'>),
#  ('purpose', <Label.NOUN: 'NOUN'>),
#  ('question', <Label.NOUN: 'NOUN'>),
#  ('range', <Label.NOUN: 'NOUN'>),
#  ('rate', <Label.NOUN: 'NOUN'>),
#  ('rest', <Label.NOUN: 'NOUN'>),
#  ('result', <Label.NOUN: 'NOUN'>),
#  ('road', <Label.NOUN: 'NOUN'>),
#  ('said', <Label.PREP: 'PREP'>),
#  ('saw', <Label.PREP: 'PREP'>),
#  ('seemed', <Label.PREP: 'PREP'>),
#  ('sense', <Label.NOUN: 'NOUN'>),
#  ('series', <Label.NOUN: 'NOUN'>),
#  ('set', <Label.NOUN: 'NOUN'>),
#  ('she', <Label.PRO: 'PRO'>),
#  ('side', <Label.NOUN: 'NOUN'>),
#  ('since', <Label.PREP: 'PREP'>),
#  ('soon', <Label.ADV: 'ADV'>),
#  ('sort', <Label.NOUN: 'NOUN'>),
#  ('sound', <Label.NOUN: 'NOUN'>),
#  ('source', <Label.NOUN: 'NOUN'>),
#  ('state', <Label.NOUN: 'NOUN'>),
#  ('still', <Label.PREP: 'PREP'>),
#  ('study', <Label.NOUN: 'NOUN'>),
#  ('surface', <Label.NOUN: 'NOUN'>),
#  ('table', <Label.NOUN: 'NOUN'>),
#  ('that', <Label.PREP: 'PREP'>),
#  ('the', <Label.DET: 'DET'>),
#  ('then', <Label.PREP: 'PREP'>),
#  ('there', <Label.PRO: 'PRO'>),
#  ('they', <Label.PRO: 'PRO'>),
#  ('though', <Label.PREP: 'PREP'>),
#  ('through', <Label.PREP: 'PREP'>),
#  ('time', <Label.NOUN: 'NOUN'>),
#  ('to', <Label.PREP: 'PREP'>),
#  ('took', <Label.PREP: 'PREP'>),
#  ('top', <Label.NOUN: 'NOUN'>),
#  ('toward', <Label.PREP: 'PREP'>),
#  ('type', <Label.NOUN: 'NOUN'>),
#  ('under', <Label.PREP: 'PREP'>),
#  ('up', <Label.PREP: 'PREP'>),
#  ('upon', <Label.PREP: 'PREP'>),
#  ('use', <Label.NOUN: 'NOUN'>),
#  ('value', <Label.NOUN: 'NOUN'>),
#  ('variety', <Label.NOUN: 'NOUN'>),
#  ('wall', <Label.NOUN: 'NOUN'>),
#  ('wanted', <Label.PREP: 'PREP'>),
#  ('was', <Label.PREP: 'PREP'>),
#  ('way', <Label.NOUN: 'NOUN'>),
#  ('went', <Label.PREP: 'PREP'>),
#  ('were', <Label.PREP: 'PREP'>),
#  ('what', <Label.PREP: 'PREP'>),
#  ('when', <Label.PREP: 'PREP'>),
#  ('where', <Label.PREP: 'PREP'>),
#  ('which', <Label.PREP: 'PREP'>),
#  ('window', <Label.NOUN: 'NOUN'>),
#  ('with', <Label.PREP: 'PREP'>),
#  ('woman', <Label.NOUN: 'NOUN'>),
#  ('work', <Label.NOUN: 'NOUN'>),
#  ('world', <Label.NOUN: 'NOUN'>),
#  ('would', <Label.PREP: 'PREP'>)}

# %%
mdl.lexicon
# Out:
# defaultdict(<function __main__.Model.<lambda>.<locals>.<lambda>()>,
#             {'you': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: inf,
#                           <Label.PREP: 'PREP'>: -18.25}),
#              'we': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: inf,
#                           <Label.PREP: 'PREP'>: -23.25}),
#              'me': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: inf, <Label.PREP: 'PREP'>: 1}),
#              'come': defaultdict(int,
#                          {<Label.VERB: 'VERB'>: inf, <Label.PREP: 'PREP'>: 1}),
#              'play': defaultdict(int,
#                          {<Label.VERB: 'VERB'>: inf,
#                           <Label.PREP: 'PREP'>: 2.25,
#                           <Label.NOUN: 'NOUN'>: -0.5}),
#              'put': defaultdict(int,
#                          {<Label.VERB: 'VERB'>: inf,
#                           <Label.PREP: 'PREP'>: 19}),
#              'on': defaultdict(int, {<Label.PREP: 'PREP'>: inf}),
#              'out': defaultdict(int, {<Label.PREP: 'PREP'>: inf}),
#              'in': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: inf,
#                           <Label.CONJ: 'CONJ'>: -392.5,
#                           <Label.NOUN: 'NOUN'>: -31.25}),
#              'this': defaultdict(int,
#                          {<Label.DET: 'DET'>: inf,
#                           <Label.PREP: 'PREP'>: -46.0,
#                           <Label.PRO: 'PRO'>: -11.75}),
#              'these': defaultdict(int,
#                          {<Label.DET: 'DET'>: inf, <Label.PREP: 'PREP'>: 1}),
#              'baby': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: inf,
#                           <Label.ADV: 'ADV'>: -2.75}),
#              'car': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: inf,
#                           <Label.PREP: 'PREP'>: -6.5}),
#              'train': defaultdict(int, {<Label.NOUN: 'NOUN'>: inf}),
#              'box': defaultdict(int, {<Label.NOUN: 'NOUN'>: inf}),
#              'house': defaultdict(int, {<Label.NOUN: 'NOUN'>: inf}),
#              'boy': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: inf,
#                           <Label.PREP: 'PREP'>: -4.25}),
#              'man': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: inf,
#                           <Label.PREP: 'PREP'>: -21.5}),
#              'book': defaultdict(int, {<Label.NOUN: 'NOUN'>: inf}),
#              'big': defaultdict(int,
#                          {<Label.ADJ: 'ADJ'>: inf,
#                           <Label.ADV: 'ADV'>: 3.25,
#                           <Label.PREP: 'PREP'>: 0.25}),
#              'silly': defaultdict(int, {<Label.ADJ: 'ADJ'>: inf}),
#              'green': defaultdict(int,
#                          {<Label.ADJ: 'ADJ'>: inf,
#                           <Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'well': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: inf,
#                           <Label.PREP: 'PREP'>: -6.75,
#                           <Label.DET: 'DET'>: -8.0,
#                           <Label.NOUN: 'NOUN'>: -6.5}),
#              'very': defaultdict(int, {<Label.ADV: 'ADV'>: inf}),
#              'now': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: inf, <Label.PREP: 'PREP'>: 24}),
#              'and': defaultdict(int,
#                          {<Label.CONJ: 'CONJ'>: inf,
#                           <Label.PREP: 'PREP'>: 36.75,
#                           <Label.NOUN: 'NOUN'>: -18.25,
#                           <Label.PRO: 'PRO'>: -5.75}),
#              'or': defaultdict(int,
#                          {<Label.CONJ: 'CONJ'>: inf,
#                           <Label.PREP: 'PREP'>: -21.75}),
#              'but': defaultdict(int,
#                          {<Label.CONJ: 'CONJ'>: inf,
#                           <Label.PREP: 'PREP'>: 23}),
#              'little': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 3.0,
#                           <Label.NOUN: 'NOUN'>: 5.75}),
#              'much': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 37.0,
#                           <Label.PREP: 'PREP'>: -21.25}),
#              'fast': defaultdict(int, {<Label.ADV: 'ADV'>: 6}),
#              'disreputable': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'recently': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'far': defaultdict(int, {<Label.ADV: 'ADV'>: 47}),
#              'directly': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.25, <Label.PREP: 'PREP'>: 1}),
#              'pointedly': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'idle': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'rapidly': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'faded': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'long': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 63.25,
#                           <Label.NOUN: 'NOUN'>: -31.5,
#                           <Label.PREP: 'PREP'>: -22.0}),
#              'vivacious': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'soon': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 29.75,
#                           <Label.PREP: 'PREP'>: 0.0}),
#              'good': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 7.75,
#                           <Label.NOUN: 'NOUN'>: -2.75,
#                           <Label.PREP: 'PREP'>: -0.25}),
#              'inventive': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'lukewarm': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'accurately': defaultdict(int, {<Label.ADV: 'ADV'>: 3}),
#              'early': defaultdict(int, {<Label.ADV: 'ADV'>: 9}),
#              'late': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 2.75,
#                           <Label.NOUN: 'NOUN'>: 2.25}),
#              'to': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 541.25,
#                           <Label.CONJ: 'CONJ'>: -361.0}),
#              'faulty': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'human': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'still': defaultdict(int, {<Label.PREP: 'PREP'>: 25}),
#              'routine': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'immoral': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'vividly': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'that': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 175.5,
#                           <Label.DET: 'DET'>: -62.75,
#                           <Label.PRO: 'PRO'>: -6.25}),
#              'widespread': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'exactly': defaultdict(int, {<Label.PREP: 'PREP'>: 6}),
#              'clear': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: -1.0,
#                           <Label.PREP: 'PREP'>: 1.5,
#                           <Label.NOUN: 'NOUN'>: 0.25}),
#              'about': defaultdict(int, {<Label.PREP: 'PREP'>: 30}),
#              'precisely': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: -1.25, <Label.PREP: 'PREP'>: 3}),
#              'fashioned': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'not': defaultdict(int, {<Label.PREP: 'PREP'>: 145}),
#              'with': defaultdict(int, {<Label.PREP: 'PREP'>: 158}),
#              'pay': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'holding': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 4.25,
#                           <Label.NOUN: 'NOUN'>: -2.0}),
#              'many': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 5.75,
#                           <Label.PREP: 'PREP'>: 4.75}),
#              'strong': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 2.25, <Label.NOUN: 'NOUN'>: 1}),
#              'so': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 9.25,
#                           <Label.PRO: 'PRO'>: -5.75}),
#              'though': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 21.25,
#                           <Label.NOUN: 'NOUN'>: -5.75}),
#              'symbolically': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'also': defaultdict(int, {<Label.PREP: 'PREP'>: 29}),
#              'the': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -93.25,
#                           <Label.DET: 'DET'>: 126.25,
#                           <Label.CONJ: 'CONJ'>: -91.25}),
#              'whenever': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'outlining': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'note': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -4.75,
#                           <Label.NOUN: 'NOUN'>: 8.25}),
#              'at': defaultdict(int, {<Label.PREP: 'PREP'>: 191}),
#              'raising': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 2.25,
#                           <Label.NOUN: 'NOUN'>: -0.5}),
#              'while': defaultdict(int, {<Label.PREP: 'PREP'>: 12}),
#              'indirectly': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'grave': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'of': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 1083.75,
#                           <Label.CONJ: 'CONJ'>: -573.75}),
#              'likely': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'get': defaultdict(int, {<Label.PREP: 'PREP'>: 16}),
#              'as': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 87.25,
#                           <Label.NOUN: 'NOUN'>: -23.75}),
#              'determining': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'specialization': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'then': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 42.5,
#                           <Label.ADV: 'ADV'>: -3.5,
#                           <Label.PRO: 'PRO'>: 1}),
#              'against': defaultdict(int, {<Label.PREP: 'PREP'>: 25}),
#              'plentiful': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'covering': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'cover': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'therefore': defaultdict(int, {<Label.PREP: 'PREP'>: 8}),
#              'since': defaultdict(int, {<Label.PREP: 'PREP'>: 16}),
#              'makes': defaultdict(int, {<Label.PREP: 'PREP'>: 9}),
#              'called': defaultdict(int, {<Label.PREP: 'PREP'>: 22}),
#              'denied': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'insuring': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'all': defaultdict(int, {<Label.PREP: 'PREP'>: 87}),
#              'open': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 2.25,
#                           <Label.NOUN: 'NOUN'>: -0.5}),
#              'brightens': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'here': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 5.5,
#                           <Label.NOUN: 'NOUN'>: -2.5}),
#              'perform': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'had': defaultdict(int, {<Label.PREP: 'PREP'>: 214}),
#              'prevents': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'prepare': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'destroy': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'classifiers': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'faithfully': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'awarded': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'neat': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'along': defaultdict(int, {<Label.PREP: 'PREP'>: 14}),
#              'launched': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'simple': defaultdict(int, {<Label.ADV: 'ADV'>: 5}),
#              'locate': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'disassemble': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'file': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.5,
#                           <Label.NOUN: 'NOUN'>: 2}),
#              'square': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.25,
#                           <Label.NOUN: 'NOUN'>: 2.25}),
#              'hold': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 1.25,
#                           <Label.NOUN: 'NOUN'>: 0.25}),
#              'making': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 4.75,
#                           <Label.NOUN: 'NOUN'>: -1.5}),
#              'fitting': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'drill': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'across': defaultdict(int, {<Label.PREP: 'PREP'>: 26}),
#              'test': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'communicating': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'involved': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'important': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 5.75,
#                           <Label.PREP: 'PREP'>: -2.5,
#                           <Label.NOUN: 'NOUN'>: -1.25}),
#              'support': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.5,
#                           <Label.NOUN: 'NOUN'>: 1.25}),
#              'accurate': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'has': defaultdict(int, {<Label.PREP: 'PREP'>: 24}),
#              'looks': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'more': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 2.5, <Label.NOUN: 'NOUN'>: 2}),
#              'different': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'because': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 15.25,
#                           <Label.NOUN: 'NOUN'>: 0.25}),
#              'upsetting': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'after': defaultdict(int, {<Label.PREP: 'PREP'>: 36}),
#              'it': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -4.75,
#                           <Label.DET: 'DET'>: -2.25,
#                           <Label.PRO: 'PRO'>: -1.0}),
#              'for': defaultdict(int, {<Label.PREP: 'PREP'>: 170}),
#              'featuring': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'through': defaultdict(int, {<Label.PREP: 'PREP'>: 42}),
#              'orphic': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'coppery': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'brought': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'when': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 71.25,
#                           <Label.CONJ: 'CONJ'>: -34.25}),
#              'masculine': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'became': defaultdict(int, {<Label.PREP: 'PREP'>: 10}),
#              'once': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 5.25,
#                           <Label.PRO: 'PRO'>: -0.5}),
#              'large': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 4.5,
#                           <Label.PREP: 'PREP'>: -1.25,
#                           <Label.NOUN: 'NOUN'>: -0.5}),
#              'battens': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'give': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'near': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 7.5,
#                           <Label.ADV: 'ADV'>: -1.0}),
#              'where': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 21.0,
#                           <Label.CONJ: 'CONJ'>: -7.25}),
#              'requires': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'laid': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'straight': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.25, <Label.PREP: 'PREP'>: 1}),
#              'possible': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: -1.25, <Label.PREP: 'PREP'>: 3}),
#              'maintenance': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -3.5,
#                           <Label.NOUN: 'NOUN'>: 6}),
#              'holds': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'rotating': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'smoothly': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'perhaps': defaultdict(int, {<Label.PREP: 'PREP'>: 8}),
#              'supervised': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'superintend': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'serve': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'picturesque': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'they': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: 61.25,
#                           <Label.PREP: 'PREP'>: -42.5}),
#              'leave': defaultdict(int, {<Label.PREP: 'PREP'>: 8}),
#              'evenly': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'roof': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -3.5,
#                           <Label.NOUN: 'NOUN'>: 6}),
#              'from': defaultdict(int, {<Label.PREP: 'PREP'>: 131}),
#              'wind': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -2.75,
#                           <Label.NOUN: 'NOUN'>: 5}),
#              'usually': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'nourishes': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'size': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -10.25,
#                           <Label.NOUN: 'NOUN'>: 15}),
#              'shape': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -5.0,
#                           <Label.NOUN: 'NOUN'>: 8}),
#              'interest': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -5.0,
#                           <Label.NOUN: 'NOUN'>: 8}),
#              'played': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'pleasure': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'practising': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'is': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 380.0,
#                           <Label.CONJ: 'CONJ'>: -174.25,
#                           <Label.NOUN: 'NOUN'>: -159.5,
#                           <Label.PRO: 'PRO'>: -19.25}),
#              'today': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'high': defaultdict(int, {<Label.ADV: 'ADV'>: 6}),
#              'let': defaultdict(int, {<Label.PREP: 'PREP'>: 9}),
#              'tighten': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'bend': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -2.75,
#                           <Label.NOUN: 'NOUN'>: 5}),
#              'gymnastics': defaultdict(int, {<Label.PRO: 'PRO'>: 1}),
#              'record': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -2.0,
#                           <Label.NOUN: 'NOUN'>: 4}),
#              'sweeping': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'general': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.25, <Label.PREP: 'PREP'>: 1}),
#              'introducing': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'translate': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'supervising': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'without': defaultdict(int, {<Label.PREP: 'PREP'>: 8}),
#              'completes': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'low': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 2.5,
#                           <Label.NOUN: 'NOUN'>: -1.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'installing': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'supplying': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'running': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 3.5,
#                           <Label.NOUN: 'NOUN'>: -0.5,
#                           <Label.CONJ: 'CONJ'>: 0.25}),
#              'displays': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'set': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -9.0,
#                           <Label.NOUN: 'NOUN'>: 16.25}),
#              'erect': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'increases': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'plazas': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'forums': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'museums': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'follow': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'roughly': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'popular': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'expensive': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'kinesics': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'above': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 6.25,
#                           <Label.NOUN: 'NOUN'>: -2.0}),
#              'commonplace': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'supposing': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'felt': defaultdict(int, {<Label.PREP: 'PREP'>: 26}),
#              'window': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -12.5,
#                           <Label.NOUN: 'NOUN'>: 18}),
#              'conceivably': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'delivered': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'causes': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.5,
#                           <Label.NOUN: 'NOUN'>: 2}),
#              'often': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 1.5, <Label.ADV: 'ADV'>: 0.5}),
#              'see': defaultdict(int, {<Label.PREP: 'PREP'>: 13}),
#              'got': defaultdict(int, {<Label.PREP: 'PREP'>: 31}),
#              'make': defaultdict(int, {<Label.PREP: 'PREP'>: 11}),
#              'himself': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'he': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -38.25,
#                           <Label.PRO: 'PRO'>: 53.25,
#                           <Label.DET: 'DET'>: -26.5}),
#              'locking': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'doing': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'leaves': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'inflame': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'even': defaultdict(int, {<Label.PREP: 'PREP'>: 34}),
#              'patient': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.5,
#                           <Label.NOUN: 'NOUN'>: 2}),
#              'took': defaultdict(int, {<Label.PREP: 'PREP'>: 31}),
#              'young': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: -2.0, <Label.NOUN: 'NOUN'>: 4}),
#              'old': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 2.25, <Label.PREP: 'PREP'>: 1}),
#              'teeth': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: 0.25, <Label.NOUN: 'NOUN'>: 1}),
#              'visit': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 2.25,
#                           <Label.NOUN: 'NOUN'>: -0.5}),
#              'fit': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -2.0,
#                           <Label.NOUN: 'NOUN'>: 4}),
#              'started': defaultdict(int, {<Label.PREP: 'PREP'>: 14}),
#              'there': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: 16.25,
#                           <Label.PREP: 'PREP'>: -8.5,
#                           <Label.DET: 'DET'>: -8.75}),
#              'rented': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'if': defaultdict(int, {<Label.PREP: 'PREP'>: 52}),
#              'falsifying': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'concerning': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'procreation': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'commended': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'nearly': defaultdict(int, {<Label.ADV: 'ADV'>: 3}),
#              'spent': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'labrador': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'stirring': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'down': defaultdict(int, {<Label.PREP: 'PREP'>: 31}),
#              'uneasy': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'shore': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'a': defaultdict(int,
#                          {<Label.DET: 'DET'>: 22.25,
#                           <Label.PREP: 'PREP'>: -15.5,
#                           <Label.NOUN: 'NOUN'>: -20.0}),
#              'studied': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'capone': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'promptly': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'marked': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'max': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'attending': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'reported': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'distrust': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'pounded': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'california': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'notified': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'reduced': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'expected': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'charged': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'hollering': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'probably': defaultdict(int, {<Label.PREP: 'PREP'>: 7}),
#              'keeping': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'during': defaultdict(int, {<Label.PREP: 'PREP'>: 31}),
#              'under': defaultdict(int, {<Label.PREP: 'PREP'>: 16}),
#              'formidable': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'demanded': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'finally': defaultdict(int, {<Label.PREP: 'PREP'>: 7}),
#              'cool': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'covered': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'held': defaultdict(int, {<Label.PREP: 'PREP'>: 11}),
#              'both': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 7.5,
#                           <Label.PRO: 'PRO'>: -3.25}),
#              'removed': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'bottles': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'paradoxically': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'dijon': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'preparing': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'trouble': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -4.0,
#                           <Label.NOUN: 'NOUN'>: 7.25}),
#              'exiling': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'redecorating': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'refresh': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'like': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 56.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'obviously': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'solid': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'locked': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'true': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 2.25,
#                           <Label.NOUN: 'NOUN'>: -0.5}),
#              'just': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 27.75,
#                           <Label.ADV: 'ADV'>: -20.75,
#                           <Label.NOUN: 'NOUN'>: -18.25}),
#              'retell': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'apparently': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'take': defaultdict(int, {<Label.PREP: 'PREP'>: 12}),
#              'eloquence': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'by': defaultdict(int, {<Label.PREP: 'PREP'>: 99}),
#              'diverse': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.25, <Label.PREP: 'PREP'>: 1}),
#              'beautifying': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'varnish': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'givin': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'rustle': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.5,
#                           <Label.NOUN: 'NOUN'>: 2}),
#              'tell': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'was': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 753.25,
#                           <Label.CONJ: 'CONJ'>: -509.75}),
#              'always': defaultdict(int, {<Label.PREP: 'PREP'>: 13}),
#              'rancher': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'accompanied': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'surely': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 2.5,
#                           <Label.ADV: 'ADV'>: -0.25}),
#              'given': defaultdict(int, {<Label.PREP: 'PREP'>: 9}),
#              'off': defaultdict(int, {<Label.PREP: 'PREP'>: 15}),
#              'unquestionably': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'only': defaultdict(int, {<Label.PREP: 'PREP'>: 49}),
#              'few': defaultdict(int, {<Label.NOUN: 'NOUN'>: 10}),
#              'exhibits': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'reduce': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'beset': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'blocking': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'indeed': defaultdict(int, {<Label.PREP: 'PREP'>: 7}),
#              'watch': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'opposite': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.5,
#                           <Label.NOUN: 'NOUN'>: 2}),
#              'addressing': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'before': defaultdict(int, {<Label.PREP: 'PREP'>: 26}),
#              'among': defaultdict(int, {<Label.PREP: 'PREP'>: 25}),
#              'frightening': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'broke': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'justly': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'registers': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.5,
#                           <Label.NOUN: 'NOUN'>: 2}),
#              'pursues': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'actresses': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'are': defaultdict(int, {<Label.PREP: 'PREP'>: 41}),
#              'perpetuating': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'informing': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'were': defaultdict(int, {<Label.PREP: 'PREP'>: 51}),
#              'abundant': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.25, <Label.CONJ: 'CONJ'>: 1}),
#              'pillaged': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'fixed': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'salmon': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'newspaperman': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'reporter': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'negotiating': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'anarchic': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'beautiful': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'leaving': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'hard': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: -0.5, <Label.PREP: 'PREP'>: 2}),
#              'professor': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'unless': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'matter': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -39.0,
#                           <Label.NOUN: 'NOUN'>: 54.5}),
#              'overcomes': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'upon': defaultdict(int, {<Label.PREP: 'PREP'>: 16}),
#              'shoot': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'docile': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'transformation': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.5,
#                           <Label.NOUN: 'NOUN'>: 2}),
#              'cure': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'expanded': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'glorifies': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'includes': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'safe': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.25, <Label.NOUN: 'NOUN'>: 1}),
#              'aboard': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'missiles': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'quickly': defaultdict(int, {<Label.ADV: 'ADV'>: 6}),
#              'unbreakable': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'counterchallenge': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'hit': defaultdict(int, {<Label.PREP: 'PREP'>: 9}),
#              'getting': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'rigid': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'mercilessly': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'knees': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'reflected': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'spacious': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'brilliant': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'up': defaultdict(int, {<Label.PREP: 'PREP'>: 21}),
#              'stone': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'sunrise': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'wide': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 1.25,
#                           <Label.PREP: 'PREP'>: 0.25}),
#              'visions': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'intricate': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'year': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -6.75,
#                           <Label.NOUN: 'NOUN'>: 11.5}),
#              'champions': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'expresses': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'chairman': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'ended': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'jay': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'handling': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'deny': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'unreal': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'defunct': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'obsolete': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'tension': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -0.5,
#                           <Label.NOUN: 'NOUN'>: 2}),
#              'reveal': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'mirrors': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'lady': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'dancer': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'protect': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'clearly': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.5,
#                           <Label.PREP: 'PREP'>: 1.25}),
#              'secure': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'effectively': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'harmless': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'our': defaultdict(int,
#                          {<Label.DET: 'DET'>: 1.25, <Label.PREP: 'PREP'>: 1}),
#              'earthquakes': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'combines': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'simply': defaultdict(int, {<Label.PREP: 'PREP'>: 7}),
#              'be': defaultdict(int, {<Label.PREP: 'PREP'>: 26}),
#              'admits': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'why': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 7.25,
#                           <Label.PRO: 'PRO'>: -0.5}),
#              'accommodates': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'partner': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'captures': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'than': defaultdict(int, {<Label.PREP: 'PREP'>: 13}),
#              'slack': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'numerous': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'particularly': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'using': defaultdict(int, {<Label.PREP: 'PREP'>: 6}),
#              'prophet': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'i': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: 40.25,
#                           <Label.PREP: 'PREP'>: -18.5}),
#              'whatever': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'thrusts': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'merry': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'liberal': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.25, <Label.NOUN: 'NOUN'>: 1}),
#              'reap': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'fill': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'ignores': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'into': defaultdict(int, {<Label.PREP: 'PREP'>: 127}),
#              'experienced': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'celebrates': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'last': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -5.75,
#                           <Label.NOUN: 'NOUN'>: 9}),
#              'campaign': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'charles': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'dominates': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'followed': defaultdict(int, {<Label.PREP: 'PREP'>: 8}),
#              'almost': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'healthy': defaultdict(int,
#                          {<Label.ADV: 'ADV'>: 0.25, <Label.PREP: 'PREP'>: 1}),
#              'corporations': defaultdict(int, {<Label.PRO: 'PRO'>: 1}),
#              'enters': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'girl': defaultdict(int, {<Label.NOUN: 'NOUN'>: 14}),
#              'discussion': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -2.75,
#                           <Label.NOUN: 'NOUN'>: 3.25,
#                           <Label.DET: 'DET'>: -1.25}),
#              'have': defaultdict(int, {<Label.PREP: 'PREP'>: 43}),
#              'what': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 16.5,
#                           <Label.PRO: 'PRO'>: -2.5}),
#              'host': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'difference': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'mist': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'point': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 25.75,
#                           <Label.PREP: 'PREP'>: -7.5}),
#              'reached': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'locus': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'esse': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'disruption': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'form': defaultdict(int, {<Label.NOUN: 'NOUN'>: 23}),
#              'number': defaultdict(int, {<Label.NOUN: 'NOUN'>: 127}),
#              'crisis': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'weakening': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 1.25,
#                           <Label.PREP: 'PREP'>: 0.25}),
#              'series': defaultdict(int, {<Label.NOUN: 'NOUN'>: 28}),
#              'kind': defaultdict(int, {<Label.NOUN: 'NOUN'>: 52}),
#              'response': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'visualizes': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'perception': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 0.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'defended': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'novel': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'disguise': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'replacing': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'prophesies': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'carries': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'disturb': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'writer': defaultdict(int, {<Label.NOUN: 'NOUN'>: 6}),
#              'retelling': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'sister': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'fisherman': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'tone': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'nature': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -13.25,
#                           <Label.NOUN: 'NOUN'>: 19}),
#              'unlike': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'whereas': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'haven': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'native': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'company': defaultdict(int, {<Label.NOUN: 'NOUN'>: 9}),
#              'sketching': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'sort': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 33.5,
#                           <Label.PREP: 'PREP'>: -20.5}),
#              'pile': defaultdict(int, {<Label.NOUN: 'NOUN'>: 7}),
#              'member': defaultdict(int, {<Label.NOUN: 'NOUN'>: 26}),
#              'time': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 20.75,
#                           <Label.PREP: 'PREP'>: -11.75,
#                           <Label.PRO: 'PRO'>: -23.75}),
#              'work': defaultdict(int, {<Label.NOUN: 'NOUN'>: 18}),
#              'body': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 12.25,
#                           <Label.PREP: 'PREP'>: -1.25}),
#              'within': defaultdict(int, {<Label.PREP: 'PREP'>: 12}),
#              'shelf': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'way': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 22.75,
#                           <Label.PREP: 'PREP'>: -11.25}),
#              'sentimentalize': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'indelicate': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'class': defaultdict(int, {<Label.NOUN: 'NOUN'>: 6}),
#              'type': defaultdict(int, {<Label.NOUN: 'NOUN'>: 16}),
#              'consequence': defaultdict(int, {<Label.NOUN: 'NOUN'>: 4}),
#              'concerned': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'case': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 12.75,
#                           <Label.PREP: 'PREP'>: -0.75}),
#              'conception': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'dreamer': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'stack': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'picture': defaultdict(int, {<Label.NOUN: 'NOUN'>: 11}),
#              'misrepresents': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'granted': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'knowledge': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 4.5,
#                           <Label.PREP: 'PREP'>: -0.25}),
#              'determine': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'analyzing': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'segment': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'mixture': defaultdict(int, {<Label.NOUN: 'NOUN'>: 4}),
#              'scale': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'otherwise': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'collection': defaultdict(int, {<Label.NOUN: 'NOUN'>: 6}),
#              'really': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'life': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 11.5,
#                           <Label.PREP: 'PREP'>: -5.75,
#                           <Label.PRO: 'PRO'>: -2.0}),
#              'couple': defaultdict(int, {<Label.NOUN: 'NOUN'>: 57}),
#              'group': defaultdict(int, {<Label.NOUN: 'NOUN'>: 30}),
#              'envied': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'families': defaultdict(int, {<Label.PRO: 'PRO'>: 1}),
#              'phalanx': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'her': defaultdict(int,
#                          {<Label.DET: 'DET'>: -5.0,
#                           <Label.PREP: 'PREP'>: -2.5,
#                           <Label.PRO: 'PRO'>: 6}),
#              'descendant': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'troop': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'smashed': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'fund': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'solution': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'over': defaultdict(int, {<Label.PREP: 'PREP'>: 51}),
#              'bolt': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'melted': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'fused': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'project': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'shortage': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'cathedral': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'congregation': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'cluck': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'tall': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
# ...
#              'mission': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'dales': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'knights': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'globe': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'malediction': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'fields': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'fear': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 2.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'people': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 6.5,
#                           <Label.PREP: 'PREP'>: -4.25,
#                           <Label.PRO: 'PRO'>: 1}),
#              'store': defaultdict(int, {<Label.NOUN: 'NOUN'>: 6}),
#              'closed': defaultdict(int, {<Label.PREP: 'PREP'>: 7}),
#              'mountains': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'hospital': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'scholar': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'bible': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'whyfores': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'floors': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'past': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -3.25,
#                           <Label.NOUN: 'NOUN'>: 6.25}),
#              'silent': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 0.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'string': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'guitar': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'words': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 7.25,
#                           <Label.PREP: 'PREP'>: -1.25}),
#              'brother': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'marks': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 1.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'necessarily': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'until': defaultdict(int, {<Label.PREP: 'PREP'>: 10}),
#              'south': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 4.25,
#                           <Label.PREP: 'PREP'>: 0.25}),
#              'techniques': defaultdict(int, {<Label.NOUN: 'NOUN'>: 4}),
#              'methods': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 6.25,
#                           <Label.PREP: 'PREP'>: -2.0}),
#              'introduction': defaultdict(int, {<Label.NOUN: 'NOUN'>: 6}),
#              'saxons': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'genealogies': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'concept': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'assimilation': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'literary': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'phenonenon': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'archaeological': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'germans': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'measure': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 5.25,
#                           <Label.PREP: 'PREP'>: -1.25}),
#              'drew': defaultdict(int, {<Label.PREP: 'PREP'>: 4}),
#              'health': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'disease': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'proof': defaultdict(int, {<Label.NOUN: 'NOUN'>: 4}),
#              'graduate': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'battery': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'saloon': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'cribs': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'country': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 4.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'playground': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'provided': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'greek': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'transcends': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'range': defaultdict(int, {<Label.NOUN: 'NOUN'>: 29}),
#              'banishes': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'voltaire': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25, <Label.DET: 'DET'>: 1}),
#              'expression': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: -1.25,
#                           <Label.NOUN: 'NOUN'>: 3}),
#              'microcosm': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'oresteia': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'magi': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'sophoclean': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'germanic': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'rather': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'thomas': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'cause': defaultdict(int, {<Label.NOUN: 'NOUN'>: 6}),
#              'tax': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'tithes': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'vicar': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'schoolboy': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'suite': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 1.25, <Label.DET: 'DET'>: 1}),
#              'whether': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'pynte': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'roll': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'defense': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 0.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'gift': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'report': defaultdict(int, {<Label.NOUN: 'NOUN'>: 8}),
#              'judgments': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: -0.5, <Label.NOUN: 'NOUN'>: 2}),
#              'accuracy': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'profession': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'style': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 1.5,
#                           <Label.DET: 'DET'>: -1.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'italians': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'modifications': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'darwinism': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'law': defaultdict(int, {<Label.NOUN: 'NOUN'>: 9}),
#              'confuse': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'natural': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'reflection': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'appease': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'thus': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'miracle': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'largely': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'kofanes': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'convict': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'army': defaultdict(int, {<Label.NOUN: 'NOUN'>: 4}),
#              'two': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 13.5,
#                           <Label.PREP: 'PREP'>: -8.5}),
#              'questions': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'filled': defaultdict(int, {<Label.PREP: 'PREP'>: 8}),
#              'comparison': defaultdict(int, {<Label.NOUN: 'NOUN'>: 4}),
#              'pictures': defaultdict(int, {<Label.NOUN: 'NOUN'>: 4}),
#              'investigating': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'spokesman': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'gay': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'lively': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'novelists': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'will': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 7.25,
#                           <Label.NOUN: 'NOUN'>: -4.25,
#                           <Label.PRO: 'PRO'>: -5.0}),
#              'printer': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'tour': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 0.25,
#                           <Label.NOUN: 'NOUN'>: 1}),
#              'preached': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'text': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'afternoon': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 1.25,
#                           <Label.PREP: 'PREP'>: 0.25}),
#              'porter': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'ordo': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'attained': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'how': defaultdict(int, {<Label.PREP: 'PREP'>: 8}),
#              'college': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'proctors': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'loose': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'taverns': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'fens': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'imbibed': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'undergraduates': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'falsity': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'revel': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'vigor': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'evident': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'kornbluth': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'novels': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'story': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 5.25,
#                           <Label.PREP: 'PREP'>: -2.75}),
#              'exceptions': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'men': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 14.5,
#                           <Label.PREP: 'PREP'>: -2.0,
#                           <Label.PRO: 'PRO'>: 0.25}),
#              'submerged': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'workers': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'earth': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 6.5,
#                           <Label.PREP: 'PREP'>: -2.75,
#                           <Label.PRO: 'PRO'>: -2.0}),
#              'contains': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'lewis': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'actually': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'person': defaultdict(int, {<Label.NOUN: 'NOUN'>: 7}),
#              'again': defaultdict(int, {<Label.PREP: 'PREP'>: 9}),
#              'conditioners': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'represents': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'absurd': defaultdict(int, {<Label.PREP: 'PREP'>: 2}),
#              'better': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: -1.0,
#                           <Label.PREP: 'PREP'>: 3.25}),
#              'shadow': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'eager': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'review': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'future': defaultdict(int, {<Label.NOUN: 'NOUN'>: 9}),
#              'concerns': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'minister': defaultdict(int, {<Label.NOUN: 'NOUN'>: 5}),
#              'ultimately': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'delegation': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'lion': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'prescribes': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'quality': defaultdict(int, {<Label.NOUN: 'NOUN'>: 10}),
#              'ideological': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'abandon': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'frenzy': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'enclosing': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'disorganized': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'around': defaultdict(int, {<Label.PREP: 'PREP'>: 20}),
#              'fresco': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'glimpse': defaultdict(int, {<Label.NOUN: 'NOUN'>: 6}),
#              'rattle': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'realization': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'generation': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'coordinate': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'coal': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'become': defaultdict(int, {<Label.PREP: 'PREP'>: 5}),
#              'development': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 27.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'concert': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'mention': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'sudden': defaultdict(int, {<Label.ADV: 'ADV'>: 2}),
#              'including': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'lost': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 0.25,
#                           <Label.PREP: 'PREP'>: 1}),
#              'brotherhood': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'odious': defaultdict(int, {<Label.ADV: 'ADV'>: 1}),
#              'art': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'mouthpiece': defaultdict(int, {<Label.NOUN: 'NOUN'>: 4}),
#              'marsh': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'understand': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'real': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'worldly': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'militant': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'victim': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'effective': defaultdict(int, {<Label.ADV: 'ADV'>: 3}),
#              'does': defaultdict(int,
#                          {<Label.PREP: 'PREP'>: 15.25, <Label.PRO: 'PRO'>: 1}),
#              'sung': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'duck': defaultdict(int, {<Label.PREP: 'PREP'>: 1}),
#              'false': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'aesthetic': defaultdict(int, {<Label.NOUN: 'NOUN'>: 2}),
#              'fact': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: 5.25,
#                           <Label.PREP: 'PREP'>: 0.25}),
#              'magazines': defaultdict(int, {<Label.PRO: 'PRO'>: 1}),
#              'infection': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'fever': defaultdict(int, {<Label.NOUN: 'NOUN'>: 1}),
#              'too': defaultdict(int, {<Label.PREP: 'PREP'>: 3}),
#              'park': defaultdict(int,
#                          {<Label.PRO: 'PRO'>: -0.5, <Label.NOUN: 'NOUN'>: 2}),
#              'ones': defaultdict(int, {<Label.NOUN: 'NOUN'>: 3}),
#              'full': defaultdict(int,
#                          {<Label.NOUN: 'NOUN'>: -6.5,
#                           <Label.PREP: 'PREP'>: 10}),
#              ...})
